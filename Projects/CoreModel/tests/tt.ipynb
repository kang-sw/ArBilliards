# %%
# test wang-hash
import numpy as np
x = np.arange(10000)

# %%
def wang_hash(seed):
    seed = (seed ^ 61) ^ (seed >> 16)
    seed *= 9
    seed = seed ^ (seed >> 4)
    seed *= 0x27d4eb2d
    seed = seed ^ (seed >> 15)
    seed = seed & ((1<<32)-1)
    return seed

# %%
y = [0]

for i in x:
    y.append(wang_hash(y[i]))

y = np.array(y)
y = y / np.float((1<<32)-1)

# %%
from matplotlib import pyplot as plt

plt.hist(y)
# Out:
# (array([1046.,  991.,  990.,  997., 1003., 1002.,  996., 1033.,  966.,
#          977.]),
#  array([0.        , 0.09997232, 0.19994463, 0.29991695, 0.39988926,
#         0.49986158, 0.5998339 , 0.69980621, 0.79977853, 0.89975084,
#         0.99972316]),
#  <BarContainer object of 10 artists>)
